# %% [markdown]
# # Cherry Blossoms!
#
# If we travel back in time a few months, [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were in full bloom! We don't live in Japan or DC, but we do have our fair share of the trees - buuut you sadly missed [Brooklyn Botanic Garden's annual festival](https://www.bbg.org/visit/event/sakura_matsuri_2019).
#
# We'll have to make up for it with data-driven cherry blossoms instead. Once upon a time [Data is Plural](https://tinyletter.com/data-is-plural) linked to [a dataset](http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/) about when the cherry trees blossom each year. It's a little out of date, but it's quirky in a real nice way so we're sticking with it.
#
# ## 0. Do all of your importing/setup stuff

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## 1. Read in the file using pandas, and look at the first five rows

# %%
df = pd.read_excel("KyotoFullFlower7.xls", skiprows=25)
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN              -
# 1             NaN              -
# 2             NaN              -
# 3             NaN              -
# 4             NaN              -

# %% [markdown]
# ## 2. Read in the file using pandas CORRECTLY, and look at the first five rows
#
# Hrm, how do your column names look? Read the file in again but this time add a parameter to make sure your columns look right.
#
# **TIP: The first year should be 801 AD, and it should not have any dates or anything.**

# %%
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN              -
# 1             NaN              -
# 2             NaN              -
# 3             NaN              -
# 4             NaN              -

# %% [markdown]
# ## 3. Look at the final five rows of the data

# %%
df.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## 4. Add some more NaN values

# %% [markdown]
# It looks like you should probably have some NaN/missing values earlier on in the dataset under "Reference name." Read in the file *one more time*, this time making sure all of those missing reference names actually show up as `NaN` instead of `-`.

# %%
df = df.replace(["-", "NaN"], np.nan)

# %%
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %% [markdown]
# ## 4. What source is the most common as a reference?

# %%
df['Reference Name'].value_counts().head()
# Out:
# NEWS-PAPER(ARASHIYAMA)        94
# SUGIURAKE-NIKKI               38
# MYOHOIN-HINAMIKI              32
# OYUDONONO-UENO-NIKKI          26
# OYUDONONO-UENO-NIKKI [EDA]    21
# Name: Reference Name, dtype: int64

# %% [markdown]
# ## 6. Filter the list to only include columns where the `Full-flowering date (DOY)` is not missing
#
# If you'd like to do it in two steps (which might be easier to think through), first figure out how to test whether a column is empty/missing/null/NaN, get the list of `True`/`False` values, and then later feed it to your `df`.

# %%
df_null = df[df['Full-flowering date (DOY)'].notnull()]
df_null.head()
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11  812                       92.0                401.0          1.0
# 14  815                      105.0                415.0          1.0
# 30  831                       96.0                406.0          1.0
# 50  851                      108.0                418.0          1.0
# 52  853                      104.0                414.0          1.0
#
#     Data type code          Reference Name
# 11             2.0              NIHON-KOKI
# 14             2.0              NIHON-KOKI
# 30             2.0              NIHON-KOKI
# 50             2.0  MONTOKUTENNO-JITSUROKU
# 52             2.0  MONTOKUTENNO-JITSUROKU

# %%
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %% [markdown]
# ## 7. Make a histogram of the full-flowering date
#
# Is it not showing up? Remember the "magic" command that makes graphs show up in matplotlib notebooks!

# %%
df_null['Full-flowering date (DOY)'].hist()

# %% [markdown]
# ## 8. Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
df_null['Full-flowering date (DOY)'].hist(bins=39)

# %% [markdown]
# ## 9. What's the average number of days it takes for the flowers to blossom? And how many records do we have?
#
# Answer these both with one line of code.

# %%
df_null['Full-flowering date (DOY)'].describe()
# Count: 827
# Average: 104
# Out:
# count    827.000000
# mean     104.540508
# std        6.407036
# min       86.000000
# 25%      100.000000
# 50%      105.000000
# 75%      109.000000
# max      124.000000
# Name: Full-flowering date (DOY), dtype: float64

# %% [markdown]
# ## 10. What's the average days into the year cherry flowers normally blossomed before 1900?

# %%
#df[] = df['Full-flowering date (DOY)']
#df[df.AD < 1900].mean()
df_null[df.AD > 1900]['Full-flowering date (DOY)'].mean()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 100.3125

# %% [markdown]
# ## 11. How about after 1900?

# %%
df_null[df.AD < 1900]['Full-flowering date (DOY)'].mean()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 105.20728291316527

# %% [markdown]
# ## 12. How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
df['Data type code'] = df['Data type code'].replace({
    0: 'from modern times',
    1: 'from diary description about full-bloom',
    2: 'from diary description about cherry blossom viewing party',
    3: 'from diary description about presents of cherry twigs from party participants',
    4: 'title in Japanese poetry',
    8: 'Deduced from wisteria phenology, using the relation proposed by Aono and Saito (2010)',
    9: 'Deduced from Japanese kerria phenology, using the relation proposed by Aono (2011)'
})
df['Data type code'].value_counts()
# Out:
# from diary description about cherry blossom viewing party                                454
# from diary description about full-bloom                                                  166
# from modern times                                                                        124
# title in Japanese poetry                                                                  39
# from diary description about presents of cherry twigs from party participants             30
# Deduced from wisteria phenology, using the relation proposed by Aono and Saito (2010)     11
# Deduced from Japanese kerria phenology, using the relation proposed by Aono (2011)         3
# Name: Data type code, dtype: int64

# %% [markdown]
# ## 13. Show only the years where our data was from a title in Japanese poetry

# %%
df[df['Data type code'] == 'title in Japanese poetry']
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 90     891                      109.0                419.0          5.0
# 94     895                      104.0                414.0          5.0
# 95     896                      104.0                413.0          5.0
# 122    923                      104.0                414.0          5.0
# 154    955                       89.0                330.0          5.0
# 168    969                       98.0                408.0          5.0
# 206   1007                      106.0                416.0          5.0
# 232   1033                      102.0                412.0          5.0
# 235   1036                      104.0                413.0          5.0
# 259   1060                      108.0                417.0          5.0
# 260   1061                       92.0                402.0          6.0
# 283   1084                      120.0                429.0          5.0
# 294   1095                      100.0                410.0          5.0
# 381   1182                      104.0                414.0          6.0
# 389   1190                      112.0                422.0          5.0
# 400   1201                       96.0                406.0          5.0
# 415   1216                      101.0                410.0          5.0
# 418   1219                      101.0                411.0          5.0
# 420   1221                       99.0                409.0          5.0
# 422   1223                      116.0                426.0          5.0
# 435   1236                       87.0                327.0          7.0
# 464   1265                       98.0                408.0          6.0
# 467   1268                      103.0                412.0          6.0
# 468   1269                      100.0                410.0          3.0
# 470   1271                      100.0                410.0          5.0
# 488   1289                      107.0                417.0          3.0
# 500   1301                       95.0                405.0          4.0
# 523   1324                       98.0                407.0          5.0
# 529   1330                      108.0                418.0          7.0
# 646   1447                      111.0                421.0          3.0
# 652   1453                      107.0                417.0          3.0
# 653   1454                      105.0                415.0          3.0
# 673   1474                       98.0                408.0          3.0
# 733   1534                      108.0                418.0          3.0
# 791   1592                       98.0                407.0          4.0
# 839   1640                      103.0                412.0          3.0
# 860   1661                       93.0                403.0          7.0
# 1045  1846                       98.0                408.0          4.0
# 1062  1863                      118.0                428.0          4.0
#
#                 Data type code              Reference Name
# 90    title in Japanese poetry                NIHONKIRYAKU
# 94    title in Japanese poetry                NIHONKIRYAKU
# 95    title in Japanese poetry     NIPPON-SANDAI-JITSUROKU
# 122   title in Japanese poetry          ZOKU-KOKIN-WAKASHU
# 154   title in Japanese poetry                     SHUISHO
# 168   title in Japanese poetry                NIHONKIRYAKU
# 206   title in Japanese poetry              MIDO-KAMPAKUKI
# 232   title in Japanese poetry                NIHONKIRYAKU
# 235   title in Japanese poetry                NIHONKIRYAKU
# 259   title in Japanese poetry         SHIN-SENZAI-WAKASHU
# 260   title in Japanese poetry                MOROZANE-SHU
# 283   title in Japanese poetry          ZOKU-GOSEN-WAKASHU
# 294   title in Japanese poetry                     CHUYUKI
# 381   title in Japanese poetry  TSUKIMOUDE-WAKASHU(PART-3)
# 389   title in Japanese poetry                SHUGYOKU-SHU
# 400   title in Japanese poetry           INOKUMA-KAMPAKUKI
# 415   title in Japanese poetry            JUNTOKUIN-GYOSHU
# 418   title in Japanese poetry            JUNTOKUIN-GYOSHU
# 420   title in Japanese poetry                   SHUI-GUSO
# 422   title in Japanese poetry              MITSUTSUNE-SHU
# 435   title in Japanese poetry              SHIIBA-WAKASHU
# 464   title in Japanese poetry                  TAMEIE-SHU
# 467   title in Japanese poetry                  TAMEIE-SHU
# 468   title in Japanese poetry               ZOKU-SHIGUSHO
# 470   title in Japanese poetry         DAINAGON-TAMEIE-SHU
# 488   title in Japanese poetry         NAKANOTSUKASA-NIKKI
# 500   title in Japanese poetry                SANEMI-KYOKI
# 523   title in Japanese poetry        HANAZONOTENNO-SHINKI
# 529   title in Japanese poetry               RINEI-WAKASHU
# 646   title in Japanese poetry                    SOKONSHU
# 652   title in Japanese poetry                    SOKONSHU
# 653   title in Japanese poetry                    SOKONSHU
# 673   title in Japanese poetry              ENROKUCHOKASHU
# 733   title in Japanese poetry      GONARAIN-GYOSEI-BASSHO
# 791   title in Japanese poetry             TOKITSUNE-KYOKI
# 839   title in Japanese poetry                  KYOHAKUSHU
# 860   title in Japanese poetry         BURUI-GENYO-WAKASHU
# 1045  title in Japanese poetry                  TEIEN-EISO
# 1062  title in Japanese poetry                  YATAKA-SHU

# %% [markdown]
# ## 14. Graph the full-flowering date (DOY) over time

# %%
#df['Full-flowering date (DOY)'].plot(x='datetime', y='close')
#df.plot(x='datetime', y='close', figsize=(16, 4), color='green', linestyle='--', marker='.')
df.plot(x='AD', y='Full-flowering date (DOY)', kind='line', figsize=(16, 4))

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# (We're only looking at the final 5)

# %%
df.rolling(10, on='AD', min_periods=5)['Full-flowering date (DOY)'].mean().tail()
# Out:
# 1210    95.9
# 1211    96.9
# 1212    96.4
# 1213    96.6
# 1214    96.0
# Name: Full-flowering date (DOY), dtype: float64

# %%
df['rolling_date'] = df.rolling(20, on='AD', min_periods=5)['Full-flowering date (DOY)'].mean()
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#   Data type code Reference Name  rolling_date
# 0            NaN            NaN           NaN
# 1            NaN            NaN           NaN
# 2            NaN            NaN           NaN
# 3            NaN            NaN           NaN
# 4            NaN            NaN           NaN

# %%
df.plot(x='AD', y='rolling_date', ylim=(80, 120), figsize=(16, 4))

# %% [markdown]
# Use the code above to create a new column called `rolling_date` in our dataset. It should be the 20-year rolling average of the flowering date. Then plot it, with the year on the x axis and the day of the year on the y axis.
#
# Try adding `ylim=(80, 120)` to your `.plot` command to make things look a little less dire.

# %% [markdown]
# ### 16. Add a month column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.
#
# **I've given you March as an example**, you just need to add in two more lines to do April and May.

# %%
df.loc[df['Full-flowering date'] < 400, 'month'] = 'March'

# %%
df.loc[df['Full-flowering date'] < 500, 'month'] = 'April'

# %%
df.loc[df['Full-flowering date'] < 600, 'month'] = 'May'

# %%
df[df.month == 'April']
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11     812                       92.0                401.0          1.0
# 14     815                      105.0                415.0          1.0
# 30     831                       96.0                406.0          1.0
# 50     851                      108.0                418.0          1.0
# 52     853                      104.0                414.0          1.0
# 63     864                      100.0                409.0          1.0
# 65     866                      106.0                416.0          1.0
# 68     869                       95.0                405.0          5.0
# 88     889                      104.0                414.0          5.0
# 90     891                      109.0                419.0          5.0
# 91     892                      108.0                417.0          5.0
# 93     894                      106.0                416.0          5.0
# 94     895                      104.0                414.0          5.0
# 95     896                      104.0                413.0          5.0
# 101    902                      102.0                412.0          5.0
# 107    908                       98.0                407.0          5.0
# 111    912                       95.0                404.0          1.0
# 112    913                      110.0                420.0          5.0
# 116    917                       95.0                405.0          1.0
# 122    923                      104.0                414.0          5.0
# 125    926                       98.0                408.0          1.0
# 129    930                       97.0                407.0          5.0
# 132    933                      106.0                416.0          5.0
# 140    941                      109.0                419.0          1.0
# 148    949                      107.0                417.0          1.0
# 149    950                       95.0                405.0          4.0
# 156    957                      112.0                422.0          1.0
# 157    958                      109.0                419.0          1.0
# 158    959                       97.0                407.0          3.0
# 159    960                      101.0                410.0          3.0
# ...    ...                        ...                  ...          ...
# 1184  1985                       99.0                409.0          3.0
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#                                          Data type code  \
# 11    from diary description about cherry blossom vi...
# 14    from diary description about cherry blossom vi...
# 30    from diary description about cherry blossom vi...
# 50    from diary description about cherry blossom vi...
# 52    from diary description about cherry blossom vi...
# 63    from diary description about cherry blossom vi...
# 65    from diary description about cherry blossom vi...
# 68    from diary description about cherry blossom vi...
# 88    from diary description about cherry blossom vi...
# 90                             title in Japanese poetry
# 91    from diary description about presents of cherr...
# 93    from diary description about cherry blossom vi...
# 94                             title in Japanese poetry
# 95                             title in Japanese poetry
# 101   Deduced from wisteria phenology, using the rel...
# 107   Deduced from wisteria phenology, using the rel...
# 111   from diary description about cherry blossom vi...
# 112   from diary description about cherry blossom vi...
# 116   from diary description about cherry blossom vi...
# 122                            title in Japanese poetry
# 125   from diary description about cherry blossom vi...
# 129   Deduced from wisteria phenology, using the rel...
# 132   Deduced from wisteria phenology, using the rel...
# 140   from diary description about cherry blossom vi...
# 148   from diary description about cherry blossom vi...
# 149   from diary description about cherry blossom vi...
# 156   from diary description about cherry blossom vi...
# 157   from diary description about cherry blossom vi...
# 158   from diary description about cherry blossom vi...
# 159   from diary description about cherry blossom vi...
# ...                                                 ...
# 1184                                  from modern times
# 1185                                  from modern times
# 1186                                  from modern times
# 1187                                  from modern times
# 1188                                  from modern times
# 1190                                  from modern times
# 1191                                  from modern times
# 1192                                  from modern times
# 1193                                  from modern times
# 1194                                  from modern times
# 1195                                  from modern times
# 1196                                  from modern times
# 1197                                  from modern times
# 1198                                  from modern times
# 1199                                  from modern times
# 1200                                  from modern times
# 1201                                  from modern times
# 1202                                  from modern times
# 1203                                  from modern times
# 1204                                  from modern times
# 1205                                  from modern times
# 1206                                  from modern times
# 1207                                  from modern times
# 1208                                  from modern times
# 1209                                  from modern times
# 1210                                  from modern times
# 1211                                  from modern times
# 1212                                  from modern times
# 1213                                  from modern times
# 1214                                  from modern times
#
#                   Reference Name  rolling_date  month
# 11                    NIHON-KOKI           NaN  April
# 14                    NIHON-KOKI           NaN  April
# 30                    NIHON-KOKI           NaN  April
# 50        MONTOKUTENNO-JITSUROKU           NaN  April
# 52        MONTOKUTENNO-JITSUROKU           NaN  April
# 63       NIPPON-SANDAI-JITSUROKU           NaN  April
# 65       NIPPON-SANDAI-JITSUROKU           NaN  April
# 68                  KANKE-BUNSOU    102.600000  April
# 88       NIPPON-SANDAI-JITSUROKU           NaN  April
# 90                  NIHONKIRYAKU           NaN  April
# 91           FUSHIMIIN-GOKIROKKU           NaN  April
# 93                  KANKE-BUNSOU           NaN  April
# 94                  NIHONKIRYAKU    106.200000  April
# 95       NIPPON-SANDAI-JITSUROKU    105.833333  April
# 101   EST-from-WF(NIHONGI-RYAKU)    105.285714  April
# 107    EST-from-WF(KIMITADA-SHU)    104.375000  April
# 111                  SHINGISHIKI    101.500000  April
# 112                 SHUI-WAKASHU    102.714286  April
# 116                     KINHISHO    100.000000  April
# 122           ZOKU-KOKIN-WAKASHU    100.400000  April
# 125                 NIHONKIRYAKU    100.000000  April
# 129    EST-from-WF(SHIRYO-SORAN)     99.833333  April
# 132    EST-from-WF(SHIRYO-SORAN)    100.000000  April
# 140                 NIHONKIRYAKU    102.800000  April
# 148                 NIHONKIRYAKU           NaN  April
# 149              DAINIHON-SHIRYO           NaN  April
# 156                 NIHONKIRYAKU    102.400000  April
# 157                 NIHONKIRYAKU    103.500000  April
# 158                      KYUREKI    102.571429  April
# 159                      KYUREKI    102.375000  April
# ...                          ...           ...    ...
# 1184      NEWS-PAPER(ARASHIYAMA)     99.400000  April
# 1185      NEWS-PAPER(ARASHIYAMA)     99.650000  April
# 1186      NEWS-PAPER(ARASHIYAMA)     99.550000  April
# 1187      NEWS-PAPER(ARASHIYAMA)     99.900000  April
# 1188      NEWS-PAPER(ARASHIYAMA)     99.500000  April
# 1190      NEWS-PAPER(ARASHIYAMA)     98.500000  April
# 1191      NEWS-PAPER(ARASHIYAMA)     98.250000  April
# 1192      NEWS-PAPER(ARASHIYAMA)     98.250000  April
# 1193      NEWS-PAPER(ARASHIYAMA)     98.250000  April
# 1194      NEWS-PAPER(ARASHIYAMA)     98.200000  April
# 1195      NEWS-PAPER(ARASHIYAMA)     98.400000  April
# 1196      NEWS-PAPER(ARASHIYAMA)     98.600000  April
# 1197      NEWS-PAPER(ARASHIYAMA)     97.950000  April
# 1198      NEWS-PAPER(ARASHIYAMA)     97.800000  April
# 1199      NEWS-PAPER(ARASHIYAMA)     97.700000  April
# 1200      NEWS-PAPER(ARASHIYAMA)     97.550000  April
# 1201      NEWS-PAPER(ARASHIYAMA)     97.450000  April
# 1202      NEWS-PAPER(ARASHIYAMA)     97.400000  April
# 1203      NEWS-PAPER(ARASHIYAMA)     96.550000  April
# 1204      NEWS-PAPER(ARASHIYAMA)     96.550000  April
# 1205      NEWS-PAPER(ARASHIYAMA)     96.350000  April
# 1206      NEWS-PAPER(ARASHIYAMA)     96.450000  April
# 1207      NEWS-PAPER(ARASHIYAMA)     95.900000  April
# 1208      NEWS-PAPER(ARASHIYAMA)     96.000000  April
# 1209      NEWS-PAPER(ARASHIYAMA)     96.350000  April
# 1210      NEWS-PAPER(ARASHIYAMA)     96.450000  April
# 1211      NEWS-PAPER(ARASHIYAMA)     96.800000  April
# 1212      NEWS-PAPER(ARASHIYAMA)     96.600000  April
# 1213      NEWS-PAPER(ARASHIYAMA)     96.350000  April
# 1214      NEWS-PAPER(ARASHIYAMA)     96.050000  April
#
# [814 rows x 8 columns]

# %% [markdown]
# ### 17. Using your new column, how many blossomings happened in each month?

# %%
df.month.value_counts()
# Out:
# April    814
# March     10
# May        3
# Name: month, dtype: int64

# %% [markdown]
# ### 18. Graph how many blossomings happened in each month.

# %%
df.month.value_counts().plot(kind='barh')

# %% [markdown]
# ## 19. Adding a day-of-month column
#
# Now we're going to add a new column called "day of month." It's actually a little tougher than it should be since the `Full-flowering date` column is a *float* instead of an integer.

# %%
df_null.head()
#df['day of month']
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11  812                       92.0                401.0          1.0
# 14  815                      105.0                415.0          1.0
# 30  831                       96.0                406.0          1.0
# 50  851                      108.0                418.0          1.0
# 52  853                      104.0                414.0          1.0
#
#     Data type code          Reference Name
# 11             2.0              NIHON-KOKI
# 14             2.0              NIHON-KOKI
# 30             2.0              NIHON-KOKI
# 50             2.0  MONTOKUTENNO-JITSUROKU
# 52             2.0  MONTOKUTENNO-JITSUROKU

# %% [markdown]
# And if you try to convert it to an int, **pandas yells at you!**

# %%
#df['Full-flowering date'].astype(int)

# %% [markdown]
# That's because, as you can read, you can't have an `NaN` be an integer. But, for some reason, it *can* be a float. Ugh! So what we'll do is **drop all of the na values, then convert them to integers to get rid of the decimals.**
#
# I'll show you the first 5 here.

# %%
df['Full-flowering date'].dropna().astype(int).head()
# Out:
# 11    401
# 14    415
# 30    406
# 50    418
# 52    414
# Name: Full-flowering date, dtype: int64

# %% [markdown]
# On the next line, I take the first character of the row and add a bunch of exclamation points on it. I want you to edit this code to **return the last TWO digits of the number**. This only shows you the first 5, by the way.
#
# You might want to look up 'list slicing.'

# %%
df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: value[-2:]).head()
# Out:
# 11    01
# 14    15
# 30    06
# 50    18
# 52    14
# Name: Full-flowering date, dtype: object

# %% [markdown]
# Now that you've successfully extracted the last two letters, save them into a new column called `'day-of-month'`

# %%
df['day-of-month'] = df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: value[-2:])

# %%
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0      801                        NaN                  NaN          NaN
# 1      802                        NaN                  NaN          NaN
# 2      803                        NaN                  NaN          NaN
# 3      804                        NaN                  NaN          NaN
# 4      805                        NaN                  NaN          NaN
# 5      806                        NaN                  NaN          NaN
# 6      807                        NaN                  NaN          NaN
# 7      808                        NaN                  NaN          NaN
# 8      809                        NaN                  NaN          NaN
# 9      810                        NaN                  NaN          NaN
# 10     811                        NaN                  NaN          NaN
# 11     812                       92.0                401.0          1.0
# 12     813                        NaN                  NaN          NaN
# 13     814                        NaN                  NaN          NaN
# 14     815                      105.0                415.0          1.0
# 15     816                        NaN                  NaN          NaN
# 16     817                        NaN                  NaN          NaN
# 17     818                        NaN                  NaN          NaN
# 18     819                        NaN                  NaN          NaN
# 19     820                        NaN                  NaN          NaN
# 20     821                        NaN                  NaN          NaN
# 21     822                        NaN                  NaN          NaN
# 22     823                        NaN                  NaN          NaN
# 23     824                        NaN                  NaN          NaN
# 24     825                        NaN                  NaN          NaN
# 25     826                        NaN                  NaN          NaN
# 26     827                        NaN                  NaN          NaN
# 27     828                        NaN                  NaN          NaN
# 28     829                        NaN                  NaN          NaN
# 29     830                        NaN                  NaN          NaN
# ...    ...                        ...                  ...          ...
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1189  1990                       88.0                329.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#                                          Data type code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    from diary description about cherry blossom vi...
# 12                                                  NaN
# 13                                                  NaN
# 14    from diary description about cherry blossom vi...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185                                  from modern times
# 1186                                  from modern times
# 1187                                  from modern times
# 1188                                  from modern times
# 1189                                  from modern times
# 1190                                  from modern times
# 1191                                  from modern times
# 1192                                  from modern times
# 1193                                  from modern times
# 1194                                  from modern times
# 1195                                  from modern times
# 1196                                  from modern times
# 1197                                  from modern times
# 1198                                  from modern times
# 1199                                  from modern times
# 1200                                  from modern times
# 1201                                  from modern times
# 1202                                  from modern times
# 1203                                  from modern times
# 1204                                  from modern times
# 1205                                  from modern times
# 1206                                  from modern times
# 1207                                  from modern times
# 1208                                  from modern times
# 1209                                  from modern times
# 1210                                  from modern times
# 1211                                  from modern times
# 1212                                  from modern times
# 1213                                  from modern times
# 1214                                  from modern times
#
#               Reference Name  rolling_date  month day-of-month
# 0                        NaN           NaN    NaN          NaN
# 1                        NaN           NaN    NaN          NaN
# 2                        NaN           NaN    NaN          NaN
# 3                        NaN           NaN    NaN          NaN
# 4                        NaN           NaN    NaN          NaN
# 5                        NaN           NaN    NaN          NaN
# 6                        NaN           NaN    NaN          NaN
# 7                        NaN           NaN    NaN          NaN
# 8                        NaN           NaN    NaN          NaN
# 9                        NaN           NaN    NaN          NaN
# 10                       NaN           NaN    NaN          NaN
# 11                NIHON-KOKI           NaN  April           01
# 12                       NaN           NaN    NaN          NaN
# 13                       NaN           NaN    NaN          NaN
# 14                NIHON-KOKI           NaN  April           15
# 15                       NaN           NaN    NaN          NaN
# 16                       NaN           NaN    NaN          NaN
# 17                       NaN           NaN    NaN          NaN
# 18                       NaN           NaN    NaN          NaN
# 19                       NaN           NaN    NaN          NaN
# 20                       NaN           NaN    NaN          NaN
# 21                       NaN           NaN    NaN          NaN
# 22                       NaN           NaN    NaN          NaN
# 23                       NaN           NaN    NaN          NaN
# 24                       NaN           NaN    NaN          NaN
# 25                       NaN           NaN    NaN          NaN
# 26                       NaN           NaN    NaN          NaN
# 27                       NaN           NaN    NaN          NaN
# 28                       NaN           NaN    NaN          NaN
# 29                       NaN           NaN    NaN          NaN
# ...                      ...           ...    ...          ...
# 1185  NEWS-PAPER(ARASHIYAMA)         99.65  April           12
# 1186  NEWS-PAPER(ARASHIYAMA)         99.55  April           05
# 1187  NEWS-PAPER(ARASHIYAMA)         99.90  April           15
# 1188  NEWS-PAPER(ARASHIYAMA)         99.50  April           03
# 1189  NEWS-PAPER(ARASHIYAMA)         98.55  March           29
# 1190  NEWS-PAPER(ARASHIYAMA)         98.50  April           07
# 1191  NEWS-PAPER(ARASHIYAMA)         98.25  April           03
# 1192  NEWS-PAPER(ARASHIYAMA)         98.25  April           07
# 1193  NEWS-PAPER(ARASHIYAMA)         98.25  April           09
# 1194  NEWS-PAPER(ARASHIYAMA)         98.20  April           09
# 1195  NEWS-PAPER(ARASHIYAMA)         98.40  April           12
# 1196  NEWS-PAPER(ARASHIYAMA)         98.60  April           07
# 1197  NEWS-PAPER(ARASHIYAMA)         97.95  April           01
# 1198  NEWS-PAPER(ARASHIYAMA)         97.80  April           04
# 1199  NEWS-PAPER(ARASHIYAMA)         97.70  April           09
# 1200  NEWS-PAPER(ARASHIYAMA)         97.55  April           06
# 1201  NEWS-PAPER(ARASHIYAMA)         97.45  April           01
# 1202  NEWS-PAPER(ARASHIYAMA)         97.40  April           08
# 1203  NEWS-PAPER(ARASHIYAMA)         96.55  April           01
# 1204  NEWS-PAPER(ARASHIYAMA)         96.55  April           09
# 1205  NEWS-PAPER(ARASHIYAMA)         96.35  April           08
# 1206  NEWS-PAPER(ARASHIYAMA)         96.45  April           07
# 1207  NEWS-PAPER(ARASHIYAMA)         95.90  April           04
# 1208  NEWS-PAPER(ARASHIYAMA)         96.00  April           05
# 1209  NEWS-PAPER(ARASHIYAMA)         96.35  April           05
# 1210  NEWS-PAPER(ARASHIYAMA)         96.45  April           09
# 1211  NEWS-PAPER(ARASHIYAMA)         96.80  April           10
# 1212  NEWS-PAPER(ARASHIYAMA)         96.60  April           03
# 1213  NEWS-PAPER(ARASHIYAMA)         96.35  April           04
# 1214  NEWS-PAPER(ARASHIYAMA)         96.05  April           03
#
# [1215 rows x 9 columns]

# %% [markdown]
# ### 20. Adding a date column
#
# Now take the `'month'` and `'day-of-month'` columns and combine them in order to create a new column called `'date'`

# %%
df['date'] = df['month'] + " " + df['day-of-month']

# %%
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0      801                        NaN                  NaN          NaN
# 1      802                        NaN                  NaN          NaN
# 2      803                        NaN                  NaN          NaN
# 3      804                        NaN                  NaN          NaN
# 4      805                        NaN                  NaN          NaN
# 5      806                        NaN                  NaN          NaN
# 6      807                        NaN                  NaN          NaN
# 7      808                        NaN                  NaN          NaN
# 8      809                        NaN                  NaN          NaN
# 9      810                        NaN                  NaN          NaN
# 10     811                        NaN                  NaN          NaN
# 11     812                       92.0                401.0          1.0
# 12     813                        NaN                  NaN          NaN
# 13     814                        NaN                  NaN          NaN
# 14     815                      105.0                415.0          1.0
# 15     816                        NaN                  NaN          NaN
# 16     817                        NaN                  NaN          NaN
# 17     818                        NaN                  NaN          NaN
# 18     819                        NaN                  NaN          NaN
# 19     820                        NaN                  NaN          NaN
# 20     821                        NaN                  NaN          NaN
# 21     822                        NaN                  NaN          NaN
# 22     823                        NaN                  NaN          NaN
# 23     824                        NaN                  NaN          NaN
# 24     825                        NaN                  NaN          NaN
# 25     826                        NaN                  NaN          NaN
# 26     827                        NaN                  NaN          NaN
# 27     828                        NaN                  NaN          NaN
# 28     829                        NaN                  NaN          NaN
# 29     830                        NaN                  NaN          NaN
# ...    ...                        ...                  ...          ...
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1189  1990                       88.0                329.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#                                          Data type code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    from diary description about cherry blossom vi...
# 12                                                  NaN
# 13                                                  NaN
# 14    from diary description about cherry blossom vi...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185                                  from modern times
# 1186                                  from modern times
# 1187                                  from modern times
# 1188                                  from modern times
# 1189                                  from modern times
# 1190                                  from modern times
# 1191                                  from modern times
# 1192                                  from modern times
# 1193                                  from modern times
# 1194                                  from modern times
# 1195                                  from modern times
# 1196                                  from modern times
# 1197                                  from modern times
# 1198                                  from modern times
# 1199                                  from modern times
# 1200                                  from modern times
# 1201                                  from modern times
# 1202                                  from modern times
# 1203                                  from modern times
# 1204                                  from modern times
# 1205                                  from modern times
# 1206                                  from modern times
# 1207                                  from modern times
# 1208                                  from modern times
# 1209                                  from modern times
# 1210                                  from modern times
# 1211                                  from modern times
# 1212                                  from modern times
# 1213                                  from modern times
# 1214                                  from modern times
#
#               Reference Name  rolling_date  month day-of-month      date
# 0                        NaN           NaN    NaN          NaN       NaN
# 1                        NaN           NaN    NaN          NaN       NaN
# 2                        NaN           NaN    NaN          NaN       NaN
# 3                        NaN           NaN    NaN          NaN       NaN
# 4                        NaN           NaN    NaN          NaN       NaN
# 5                        NaN           NaN    NaN          NaN       NaN
# 6                        NaN           NaN    NaN          NaN       NaN
# 7                        NaN           NaN    NaN          NaN       NaN
# 8                        NaN           NaN    NaN          NaN       NaN
# 9                        NaN           NaN    NaN          NaN       NaN
# 10                       NaN           NaN    NaN          NaN       NaN
# 11                NIHON-KOKI           NaN  April           01  April 01
# 12                       NaN           NaN    NaN          NaN       NaN
# 13                       NaN           NaN    NaN          NaN       NaN
# 14                NIHON-KOKI           NaN  April           15  April 15
# 15                       NaN           NaN    NaN          NaN       NaN
# 16                       NaN           NaN    NaN          NaN       NaN
# 17                       NaN           NaN    NaN          NaN       NaN
# 18                       NaN           NaN    NaN          NaN       NaN
# 19                       NaN           NaN    NaN          NaN       NaN
# 20                       NaN           NaN    NaN          NaN       NaN
# 21                       NaN           NaN    NaN          NaN       NaN
# 22                       NaN           NaN    NaN          NaN       NaN
# 23                       NaN           NaN    NaN          NaN       NaN
# 24                       NaN           NaN    NaN          NaN       NaN
# 25                       NaN           NaN    NaN          NaN       NaN
# 26                       NaN           NaN    NaN          NaN       NaN
# 27                       NaN           NaN    NaN          NaN       NaN
# 28                       NaN           NaN    NaN          NaN       NaN
# 29                       NaN           NaN    NaN          NaN       NaN
# ...                      ...           ...    ...          ...       ...
# 1185  NEWS-PAPER(ARASHIYAMA)         99.65  April           12  April 12
# 1186  NEWS-PAPER(ARASHIYAMA)         99.55  April           05  April 05
# 1187  NEWS-PAPER(ARASHIYAMA)         99.90  April           15  April 15
# 1188  NEWS-PAPER(ARASHIYAMA)         99.50  April           03  April 03
# 1189  NEWS-PAPER(ARASHIYAMA)         98.55  March           29  March 29
# 1190  NEWS-PAPER(ARASHIYAMA)         98.50  April           07  April 07
# 1191  NEWS-PAPER(ARASHIYAMA)         98.25  April           03  April 03
# 1192  NEWS-PAPER(ARASHIYAMA)         98.25  April           07  April 07
# 1193  NEWS-PAPER(ARASHIYAMA)         98.25  April           09  April 09
# 1194  NEWS-PAPER(ARASHIYAMA)         98.20  April           09  April 09
# 1195  NEWS-PAPER(ARASHIYAMA)         98.40  April           12  April 12
# 1196  NEWS-PAPER(ARASHIYAMA)         98.60  April           07  April 07
# 1197  NEWS-PAPER(ARASHIYAMA)         97.95  April           01  April 01
# 1198  NEWS-PAPER(ARASHIYAMA)         97.80  April           04  April 04
# 1199  NEWS-PAPER(ARASHIYAMA)         97.70  April           09  April 09
# 1200  NEWS-PAPER(ARASHIYAMA)         97.55  April           06  April 06
# 1201  NEWS-PAPER(ARASHIYAMA)         97.45  April           01  April 01
# 1202  NEWS-PAPER(ARASHIYAMA)         97.40  April           08  April 08
# 1203  NEWS-PAPER(ARASHIYAMA)         96.55  April           01  April 01
# 1204  NEWS-PAPER(ARASHIYAMA)         96.55  April           09  April 09
# 1205  NEWS-PAPER(ARASHIYAMA)         96.35  April           08  April 08
# 1206  NEWS-PAPER(ARASHIYAMA)         96.45  April           07  April 07
# 1207  NEWS-PAPER(ARASHIYAMA)         95.90  April           04  April 04
# 1208  NEWS-PAPER(ARASHIYAMA)         96.00  April           05  April 05
# 1209  NEWS-PAPER(ARASHIYAMA)         96.35  April           05  April 05
# 1210  NEWS-PAPER(ARASHIYAMA)         96.45  April           09  April 09
# 1211  NEWS-PAPER(ARASHIYAMA)         96.80  April           10  April 10
# 1212  NEWS-PAPER(ARASHIYAMA)         96.60  April           03  April 03
# 1213  NEWS-PAPER(ARASHIYAMA)         96.35  April           04  April 04
# 1214  NEWS-PAPER(ARASHIYAMA)         96.05  April           03  April 03
#
# [1215 rows x 10 columns]

# %% [markdown]
# # YOU ARE DONE.
#
# And **incredible.**
