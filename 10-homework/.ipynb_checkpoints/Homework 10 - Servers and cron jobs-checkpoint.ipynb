# %% [markdown]
# ## Using APIs/Data Structures
# Using the Dark Sky Forecast API at https://developer.forecast.io/, generate a sentence that describes the weather that day.
#
# Right now it is TEMPERATURE degrees out and SUMMARY. Today will be TEMP_FEELING with a high of HIGH_TEMP and a low of LOW_TEMP. RAIN_WARNING.
#
# - TEMPERATURE is the current temperature
# - SUMMARY is what it currently looks like (partly cloudy, etc - it's "summary" in the dictionary). Lowercase, please.
# - TEMP_FEELING is whether it will be hot, warm, cold, or moderate. You will probably use HIGH_TEMP and your own thoughts and feelings to determine this.
# - HIGH_TEMP is the high temperature for the day.
# - LOW_TEMP is the low temperature for the day.
# - RAIN_WARNING is something like "bring your umbrella!" if it is going to rain at some point during the day.
#
# You can take a look at the documentation, but "current" contains the current conditions and the first element of "daily" is for the current day. But you knew that, right?!
#
# Feel free to steal your old code! I bet that trying to read it will make you depressed and teaches you the value of naming variables.
#
# Once you've accomplished that part, use Mailgun to send yourself an email every morning at 8AM telling you the sentence. The subject line of the email should be something like "8AM Weather forecast: January 1, 1970."
#
# Dates are obtained by doing something like this, using http://strftime.org/ as a reference:
#
# import datetime
# right_now = datetime.datetime.now()
# date_string = right_now.strftime("%Y-%M")
#
# BONUS: List the forecasted temperatures as the day goes on.
#
# BONUS: Set the timezone on your server so emails go out at the right time.

# %%
from dotenv import load_dotenv
load_dotenv()
import os

API_KEY = os.getenv("DARKSKY_API_KEY")
import requests

# %%
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40.7829, -73.9654') #NYC
weather = response.json()
weather.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
current = weather['currently']
#print(current)
current['temperature']
# Out:
# 84.51

# %%
weather['daily']['data']
# Out:
# [{'time': 1561348800,
#   'summary': 'Mostly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'sunriseTime': 1561368401,
#   'sunsetTime': 1561422749,
#   'moonPhase': 0.74,
#   'precipIntensity': 0.0001,
#   'precipIntensityMax': 0.001,
#   'precipIntensityMaxTime': 1561424400,
#   'precipProbability': 0.09,
#   'precipType': 'rain',
#   'temperatureHigh': 85.28,
#   'temperatureHighTime': 1561406400,
#   'temperatureLow': 70.36,
#   'temperatureLowTime': 1561464000,
#   'apparentTemperatureHigh': 85.28,
#   'apparentTemperatureHighTime': 1561406400,
#   'apparentTemperatureLow': 71.54,
#   'apparentTemperatureLowTime': 1561464000,
#   'dewPoint': 57.62,
#   'humidity': 0.56,
#   'pressure': 1011.17,
#   'windSpeed': 4.82,
#   'windGust': 15.27,
#   'windGustTime': 1561420800,
#   'windBearing': 202,
#   'cloudCover': 0.34,
#   'uvIndex': 9,
#   'uvIndexTime': 1561395600,
#   'visibility': 9.737,
#   'ozone': 322.8,
#   'temperatureMin': 64.02,
#   'temperatureMinTime': 1561370400,
#   'temperatureMax': 85.28,
#   'temperatureMaxTime': 1561406400,
#   'apparentTemperatureMin': 64.02,
#   'apparentTemperatureMinTime': 1561370400,
#   'apparentTemperatureMax': 85.28,
#   'apparentTemperatureMaxTime': 1561406400},
#  {'time': 1561435200,
#   'summary': 'Rain in the morning and afternoon.',
#   'icon': 'rain',
#   'sunriseTime': 1561454820,
#   'sunsetTime': 1561509154,
#   'moonPhase': 0.77,
#   'precipIntensity': 0.029,
#   'precipIntensityMax': 0.1515,
#   'precipIntensityMaxTime': 1561474800,
#   'precipProbability': 0.84,
#   'precipType': 'rain',
#   'temperatureHigh': 85.04,
#   'temperatureHighTime': 1561496400,
#   'temperatureLow': 70.83,
#   'temperatureLowTime': 1561546800,
#   'apparentTemperatureHigh': 88.4,
#   'apparentTemperatureHighTime': 1561496400,
#   'apparentTemperatureLow': 70.95,
#   'apparentTemperatureLowTime': 1561546800,
#   'dewPoint': 67.56,
#   'humidity': 0.76,
#   'pressure': 1009.95,
#   'windSpeed': 7.16,
#   'windGust': 19.45,
#   'windGustTime': 1561464000,
#   'windBearing': 188,
#   'cloudCover': 0.75,
#   'uvIndex': 4,
#   'uvIndexTime': 1561489200,
#   'visibility': 9.744,
#   'ozone': 325.6,
#   'temperatureMin': 70.36,
#   'temperatureMinTime': 1561464000,
#   'temperatureMax': 85.04,
#   'temperatureMaxTime': 1561496400,
#   'apparentTemperatureMin': 71.54,
#   'apparentTemperatureMinTime': 1561464000,
#   'apparentTemperatureMax': 88.4,
#   'apparentTemperatureMaxTime': 1561496400},
#  {'time': 1561521600,
#   'summary': 'Partly cloudy throughout the day.',
#   'icon': 'clear-day',
#   'sunriseTime': 1561541240,
#   'sunsetTime': 1561595558,
#   'moonPhase': 0.8,
#   'precipIntensity': 0.0001,
#   'precipIntensityMax': 0.0002,
#   'precipIntensityMaxTime': 1561579200,
#   'precipProbability': 0.02,
#   'precipType': 'rain',
#   'temperatureHigh': 87.06,
#   'temperatureHighTime': 1561579200,
#   'temperatureLow': 72.82,
#   'temperatureLowTime': 1561629600,
#   'apparentTemperatureHigh': 87.06,
#   'apparentTemperatureHighTime': 1561579200,
#   'apparentTemperatureLow': 73.45,
#   'apparentTemperatureLowTime': 1561629600,
#   'dewPoint': 61.37,
#   'humidity': 0.57,
#   'pressure': 1016.48,
#   'windSpeed': 5.08,
#   'windGust': 16.12,
#   'windGustTime': 1561521600,
#   'windBearing': 265,
#   'cloudCover': 0.12,
#   'uvIndex': 9,
#   'uvIndexTime': 1561568400,
#   'visibility': 10,
#   'ozone': 337.9,
#   'temperatureMin': 70.83,
#   'temperatureMinTime': 1561546800,
#   'temperatureMax': 87.06,
#   'temperatureMaxTime': 1561579200,
#   'apparentTemperatureMin': 70.95,
#   'apparentTemperatureMinTime': 1561546800,
#   'apparentTemperatureMax': 87.06,
#   'apparentTemperatureMaxTime': 1561579200},
#  {'time': 1561608000,
#   'summary': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'sunriseTime': 1561627662,
#   'sunsetTime': 1561681959,
#   'moonPhase': 0.83,
#   'precipIntensity': 0.0004,
#   'precipIntensityMax': 0.0021,
#   'precipIntensityMaxTime': 1561658400,
#   'precipProbability': 0.03,
#   'precipType': 'rain',
#   'temperatureHigh': 87.4,
#   'temperatureHighTime': 1561669200,
#   'temperatureLow': 73.69,
#   'temperatureLowTime': 1561712400,
#   'apparentTemperatureHigh': 87.96,
#   'apparentTemperatureHighTime': 1561669200,
#   'apparentTemperatureLow': 73.69,
#   'apparentTemperatureLowTime': 1561712400,
#   'dewPoint': 63.04,
#   'humidity': 0.57,
#   'pressure': 1019.74,
#   'windSpeed': 4.8,
#   'windGust': 18.44,
#   'windGustTime': 1561690800,
#   'windBearing': 274,
#   'cloudCover': 0.25,
#   'uvIndex': 9,
#   'uvIndexTime': 1561654800,
#   'visibility': 10,
#   'ozone': 333.1,
#   'temperatureMin': 72.82,
#   'temperatureMinTime': 1561629600,
#   'temperatureMax': 87.4,
#   'temperatureMaxTime': 1561669200,
#   'apparentTemperatureMin': 73.45,
#   'apparentTemperatureMinTime': 1561629600,
#   'apparentTemperatureMax': 87.96,
#   'apparentTemperatureMaxTime': 1561669200},
#  {'time': 1561694400,
#   'summary': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'sunriseTime': 1561714085,
#   'sunsetTime': 1561768359,
#   'moonPhase': 0.87,
#   'precipIntensity': 0,
#   'precipIntensityMax': 0,
#   'precipProbability': 0,
#   'temperatureHigh': 90.9,
#   'temperatureHighTime': 1561755600,
#   'temperatureLow': 75.48,
#   'temperatureLowTime': 1561798800,
#   'apparentTemperatureHigh': 90.9,
#   'apparentTemperatureHighTime': 1561755600,
#   'apparentTemperatureLow': 75.62,
#   'apparentTemperatureLowTime': 1561798800,
#   'dewPoint': 56.84,
#   'humidity': 0.43,
#   'pressure': 1021.67,
#   'windSpeed': 4.76,
#   'windGust': 16.99,
#   'windGustTime': 1561694400,
#   'windBearing': 320,
#   'cloudCover': 0.18,
#   'uvIndex': 7,
#   'uvIndexTime': 1561741200,
#   'visibility': 10,
#   'ozone': 321.4,
#   'temperatureMin': 73.69,
#   'temperatureMinTime': 1561712400,
#   'temperatureMax': 90.9,
#   'temperatureMaxTime': 1561755600,
#   'apparentTemperatureMin': 73.69,
#   'apparentTemperatureMinTime': 1561712400,
#   'apparentTemperatureMax': 90.9,
#   'apparentTemperatureMaxTime': 1561755600},
#  {'time': 1561780800,
#   'summary': 'Mostly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'sunriseTime': 1561800511,
#   'sunsetTime': 1561854756,
#   'moonPhase': 0.9,
#   'precipIntensity': 0.0008,
#   'precipIntensityMax': 0.0047,
#   'precipIntensityMaxTime': 1561867200,
#   'precipProbability': 0.12,
#   'precipType': 'rain',
#   'temperatureHigh': 92.22,
#   'temperatureHighTime': 1561834800,
#   'temperatureLow': 74.9,
#   'temperatureLowTime': 1561892400,
#   'apparentTemperatureHigh': 92.6,
#   'apparentTemperatureHighTime': 1561831200,
#   'apparentTemperatureLow': 75.14,
#   'apparentTemperatureLowTime': 1561892400,
#   'dewPoint': 61.29,
#   'humidity': 0.48,
#   'pressure': 1016.07,
#   'windSpeed': 7.92,
#   'windGust': 20.5,
#   'windGustTime': 1561845600,
#   'windBearing': 281,
#   'cloudCover': 0.67,
#   'uvIndex': 5,
#   'uvIndexTime': 1561831200,
#   'visibility': 10,
#   'ozone': 321.4,
#   'temperatureMin': 75.48,
#   'temperatureMinTime': 1561798800,
#   'temperatureMax': 92.22,
#   'temperatureMaxTime': 1561834800,
#   'apparentTemperatureMin': 75.62,
#   'apparentTemperatureMinTime': 1561798800,
#   'apparentTemperatureMax': 92.6,
#   'apparentTemperatureMaxTime': 1561831200},
#  {'time': 1561867200,
#   'summary': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'sunriseTime': 1561886937,
#   'sunsetTime': 1561941152,
#   'moonPhase': 0.94,
#   'precipIntensity': 0.0043,
#   'precipIntensityMax': 0.0231,
#   'precipIntensityMaxTime': 1561939200,
#   'precipProbability': 0.28,
#   'precipType': 'rain',
#   'temperatureHigh': 86.64,
#   'temperatureHighTime': 1561917600,
#   'temperatureLow': 64.04,
#   'temperatureLowTime': 1561971600,
#   'apparentTemperatureHigh': 86.64,
#   'apparentTemperatureHighTime': 1561917600,
#   'apparentTemperatureLow': 64.04,
#   'apparentTemperatureLowTime': 1561971600,
#   'dewPoint': 58.96,
#   'humidity': 0.53,
#   'pressure': 1009.63,
#   'windSpeed': 9.59,
#   'windGust': 25.25,
#   'windGustTime': 1561939200,
#   'windBearing': 317,
#   'cloudCover': 0.39,
#   'uvIndex': 6,
#   'uvIndexTime': 1561914000,
#   'visibility': 10,
#   'ozone': 346,
#   'temperatureMin': 68,
#   'temperatureMinTime': 1561953600,
#   'temperatureMax': 86.64,
#   'temperatureMaxTime': 1561917600,
#   'apparentTemperatureMin': 68,
#   'apparentTemperatureMinTime': 1561953600,
#   'apparentTemperatureMax': 86.64,
#   'apparentTemperatureMaxTime': 1561917600},
#  {'time': 1561953600,
#   'summary': 'Mostly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'sunriseTime': 1561973366,
#   'sunsetTime': 1562027545,
#   'moonPhase': 0.97,
#   'precipIntensity': 0.0001,
#   'precipIntensityMax': 0.0002,
#   'precipIntensityMaxTime': 1561989600,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperatureHigh': 79.17,
#   'temperatureHighTime': 1562007600,
#   'temperatureLow': 66.16,
#   'temperatureLowTime': 1562058000,
#   'apparentTemperatureHigh': 79.17,
#   'apparentTemperatureHighTime': 1562007600,
#   'apparentTemperatureLow': 66.16,
#   'apparentTemperatureLowTime': 1562058000,
#   'dewPoint': 55.38,
#   'humidity': 0.58,
#   'pressure': 1012.55,
#   'windSpeed': 8.81,
#   'windGust': 26.41,
#   'windGustTime': 1561968000,
#   'windBearing': 23,
#   'cloudCover': 0.28,
#   'uvIndex': 8,
#   'uvIndexTime': 1562000400,
#   'visibility': 10,
#   'ozone': 352.3,
#   'temperatureMin': 64.04,
#   'temperatureMinTime': 1561971600,
#   'temperatureMax': 79.17,
#   'temperatureMaxTime': 1562007600,
#   'apparentTemperatureMin': 64.04,
#   'apparentTemperatureMinTime': 1561971600,
#   'apparentTemperatureMax': 79.17,
#   'apparentTemperatureMaxTime': 1562007600}]

# %%
current['apparentTemperature']
# Out:
# 84.51

# %%
subject = "Your Daily Mail Forecast"
daily = weather['daily']['data']
temp_now = current['apparentTemperature']
from datetime import datetime

dates = []
for data in daily:
    date = datetime.utcfromtimestamp(data['time']).strftime('%Y-%m-%d %H:%M:%S')
    dates.append(data['time'])
    
    if min(dates) == data['time']:
        print(date)
        summary = data['summary']
        
        if data['apparentTemperatureHigh'] > 75:
            temp_feeling = "hot"
        elif data['apparentTemperatureHigh'] < 60:
            temp_feeling = "cold"
        else:
            temp_feeling = "warm"
            
        high = data['temperatureHigh']
        low = data['temperatureLow']
        
        if "rain" in data['icon']:
            rain = "Bring your umbrella! It may rain at some point during the day"
        else:
            rain = "It's not supposed to rain today"
        text = f'Right now it is {temp_now} degrees out and {summary.lower()} Today will be {temp_feeling} with a high of {high} and a low of {low}. {rain}.'
# Out:
# 2019-06-24 04:00:00

# %%
response = requests.post(
    "https://api.mailgun.net/v3/sandbox1ded04a1418f4a5cbfa3a5a9ff1975cc.mailgun.org/messages",
    auth=("api", "f1e57f9689fe943b2ef4a963d9257d71-2b778fc3-d77cf4d5"),
    data={"from": "Excited User <mailgun@sandbox1ded04a1418f4a5cbfa3a5a9ff1975cc.mailgun.org>",
        "to": ["aw3230@columbia.com"],
        "subject": subject,
        "text": text})
response.text
# Out:
# '{\n  "message": "Sandbox subdomains are for test purposes only. Please add your own domain or add the address to authorized recipients in Account Settings."\n}'
