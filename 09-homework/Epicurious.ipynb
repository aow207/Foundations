# %% [markdown]
# # Epicurious (Pagination, scraping 1x per row)
# ## Andrew Williams
#
# https://www.epicurious.com/search/cucumbers - or whatever other search term
#
# Remember, we're scraping multiple pages of search results, so the URL will be different!
#
# Scrape 10 pages of cucumber search results, and save as a CSV file. Include the following fields:
#
# - Tag/category
# - Title
# - Summary
# - Rating (We'll only want the 2, not the 2 / 4)
# - Would make again
# - Link/URL
#
# Tip: You'll need to try/escape on some of these fields

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.epicurious.com/search/lemon')
doc = BeautifulSoup(response.text)
#print(doc.prettify())

# %%
lemons = doc.find_all('article')

# %%
rows = []
for lemon in lemons:
    row = {}
    try:
        row['Tag'] = lemon.find(class_="tag").text.strip()
    except:
        pass
    try:
        row['Title'] = lemon.find(class_="hed").text.strip()
    except:
        pass
    try:
        row['Summary'] = lemon.find(class_="dek").text.strip()
    except:
        pass
    try:
        row['Rating'] = lemon.find(itemprop="ratingValue").text.strip()
    except:
        pass
    try:
        row['Again?'] = lemon.find(class_="make-again-percentage").text.strip()
    except:
        pass
    try:
        if lemon.find('a')['href'] == 'https://www.condenast.com/user-agreement/':
            continue
        else:
            row['URL'] = lemon.find('a')['href']
    except:
        pass
    rows.append(row)
rows
# Out:
# [{'Tag': 'recipe',
#   'Title': 'East 62nd Street Lemon Cake',
#   'Summary': 'The zest of two whole lemons goes into this cake batter, giving it a real punch of citrus flavor, accented by the drippy lemon glaze that gets drizzled overtop.',
#   'Rating': '4',
#   'Again?': '100%',
#   'URL': '/recipes/food/views/east-62nd-street-lemon-cake'},
#  {'Tag': 'recipe',
#   'Title': 'Lemon-Pepper Salami Bites',
#   'Summary': 'Bright citrus and fresh-ground pepper put a festive spin on two party staples: cured meat and Marcona almonds.',
#   'Rating': '0',
#   'Again?': '0%',
#   'URL': '/recipes/food/views/lemon-pepper-salami-bites'},
#  {'Tag': 'recipe',
#   'Title': 'Herb-Infused Lemon-Strawberry Loaf',
#   'Summary': 'Fresh herbs infuse this buttery lemon cake with floral flavor that beautifully complements swirls of sweet strawberry jam.',
#   'Rating': '3',
#   'Again?': '85%',
#   'URL': '/recipes/food/views/herb-infused-lemon-strawberry-loaf'},
#  {'Tag': 'recipe',
#   'Title': 'Chicken with Lemon and Spicy Spring Onions',
#   'Summary': 'Roasting two chickens on one baking sheet is an effortless but strategic way to cook for a crowd. As the fat renders, it bastes the vegetables for a built-in side dish.',
#   'Rating': '0',
#   'Again?': '0%',
#   'URL': '/recipes/food/views/chicken-with-lemon-and-spicy-spring-onions'},
#  {'Tag': 'recipe',
#   'Title': 'Potato Tart with Mustard Greens and Thyme',
#   'Summary': 'Whole wheat phyllo dough makes a crispy crust for this lively potato tart with the flavors of mustard greens, lemon thyme, and goat cheese.',
#   'Rating': '0',
#   'Again?': '0%',
#   'URL': '/recipes/food/views/potato-tart-with-mustard-greens-and-lemon-thyme'},
#  {'Tag': 'recipe',
#   'Title': 'Lemon Cake with Fruit',
#   'Summary': 'Whatever fruit you have on hand—pears, berries, figs, grapefruit—will fare beautifully in this sheet cake, which is as good for breakfast as it is dessert.',
#   'Rating': '4',
#   'Again?': '100%',
#   'URL': '/recipes/food/views/lemon-cake-with-fruit'},
#  {'Tag': 'recipe',
#   'Title': 'Lemon and Fig Cupcakes',
#   'Summary': "Earthy-sweet figs and bright lemon zest and juice give these cupcakes worlds of flavor. If you'd like, take them one step further with a silky cream cheese frosting.",
#   'Rating': '0',
#   'Again?': '0%',
#   'URL': '/recipes/food/views/lemon-and-fig-cupcakes'},
#  {'Tag': 'recipe',
#   'Title': 'Slow-Cooked Summer Squash with Lemon and Thyme',
#   'Summary': 'Cooking summer squash low and slow yields sweet, nutty, tender—but not mushy—results. They fold into pasta beautifully, but that’s just one of many ways to use them.',
#   'Rating': '0',
#   'Again?': '0%',
#   'URL': '/recipes/food/views/slow-cooked-summer-squash-with-lemon-and-thyme'},
#  {'Tag': 'recipe',
#   'Title': 'Roast Chicken with Bell Peppers, Lemon, and Thyme',
#   'Summary': 'How to pull off a weeknight roast chicken: set it over a bed of peppers laced with thyme and chiles for a two-for-one deal.',
#   'Rating': '4',
#   'Again?': '100%',
#   'URL': '/recipes/food/views/roast-chicken-with-bell-peppers-lemon-and-thyme'},
#  {'Tag': 'recipe',
#   'Title': 'Grilled Lemon-Pepper Chicken',
#   'Summary': 'If you want to go with the same flavors and basic method but prefer chicken pieces, go forth! Use skin-on, bone-in breasts and legs—total cooking time will be shorter.',
#   'Rating': '2.5',
#   'Again?': '67%',
#   'URL': '/recipes/food/views/grilled-lemon-pepper-chicken'},
#  {'Tag': 'recipe',
#   'Title': 'Slow-Cooked Eggplant with Lemon and Fennel Seeds',
#   'Summary': 'Use this master formula as your guide—but feel free to get creative with the add-ins. A dried chile? Sure! A few sprigs of herbs from your windowsill? Why not?',
#   'Rating': '4',
#   'Again?': '100%',
#   'URL': '/recipes/food/views/slow-cooked-eggplant-with-lemon-and-fennel-seeds'},
#  {'Tag': 'recipe',
#   'Title': 'Lemon-Lime Battenberg',
#   'Summary': "This is a unique and slightly peculiar British cake; you'd be hard pressed to find another baked good with the same psychedelic squares and level of geometric satisfaction.",
#   'Rating': '0',
#   'Again?': '0%',
#   'URL': '/recipes/food/views/lemon-and-lime-battenberg'},
#  {'Tag': 'video',
#   'Title': '50 People Try to Juice a Lemon',
#   'Summary': 'Juicing a lemon may not be as easy as it sounds. 50 people attempt to juice, squeeze, squash and smoosh a lemon. Do you have a favorite technique?\nLike the knives you see in this video? Grab your own set at https://www.bedbathandbeyond.com/store/brand/epicurious/4589/?ta=typeahead&ml=v2',
#   'URL': 'http://video.epicurious.com/watch/50-person-prep-challenge-50-people-try-to-juice-a-lemon'},
#  {'Tag': 'recipe',
#   'Title': 'Summer Salad with Lemon Dijon Dressing',
#   'Summary': 'In summer, raw corn kernels add crunch and sweetness to any salad and can be enjoyed freshly sliced, right off the cob.',
#   'Rating': '4',
#   'Again?': '100%',
#   'URL': '/recipes/food/views/summer-salad-with-lemon-dijon-dressing'},
#  {'Tag': 'recipe',
#   'Title': 'Grilled Pork Chops with Plums, Halloumi, and Lemon',
#   'Summary': 'Bring all your ingredients out to the grill on a baking sheet for easy cleanup later.',
#   'Rating': '0',
#   'Again?': '0%',
#   'URL': '/recipes/food/views/grilled-pork-chops-with-plums-halloumi-and-lemon'},
#  {'Tag': 'recipe',
#   'Title': 'Lemon Chicken Thighs',
#   'Summary': 'Humble white vinegar does double duty here, tenderizing chicken thighs while giving them a tart flavor accentuated by a super-easy charred lemon–garlic sauce.',
#   'Rating': '3.5',
#   'Again?': '86%',
#   'URL': '/recipes/food/views/lemon-chicken-thighs'},
#  {'Tag': 'gallery',
#   'Title': '38 Zesty Lemon Desserts',
#   'Summary': 'Sweet, sour, and utterly irresistible.',
#   'URL': '/recipes-menus/lemon-desserts-pie-tart-cake-bars-popsicles-recipes-gallery'},
#  {'Tag': 'gallery',
#   'Title': '43 Ways to Make Cheesecake',
#   'Summary': 'From classic to lemon to pumpkin-ginger.',
#   'URL': '/recipes-menus/12-excuses-to-bake-a-cheesecake-gallery'}]

# %% [markdown]
# ## Making URLs + Looping

# %%
for page_num in range(1, 11): #start num and last num + 1
    url = f"https://www.epicurious.com/search/lemon?page={page_num}"
    print(url)
# Out:
# https://www.epicurious.com/search/lemon?page=1
# https://www.epicurious.com/search/lemon?page=2
# https://www.epicurious.com/search/lemon?page=3
# https://www.epicurious.com/search/lemon?page=4
# https://www.epicurious.com/search/lemon?page=5
# https://www.epicurious.com/search/lemon?page=6
# https://www.epicurious.com/search/lemon?page=7
# https://www.epicurious.com/search/lemon?page=8
# https://www.epicurious.com/search/lemon?page=9
# https://www.epicurious.com/search/lemon?page=10

# %%
# make empty list first 
print("Making empty list")
rows = []

for page_num in range(1, 11): # 1-10
    url = f"https://www.epicurious.com/search/lemon?page={page_num}"
    print("Now scraping", url)
    
    #Download the appropriate page
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    
    #Scraping
    lemons = doc.find_all('article')
    for lemon in lemons:
        row = {}
        try:
            row['Tag'] = lemon.find(class_="tag").text.strip()
        except:
            pass
        try:
            row['Title'] = lemon.find(class_="hed").text.strip()
        except:
            pass
        try:
            row['Summary'] = lemon.find(class_="dek").text.strip()
        except:
            pass
        try:
            row['Rating'] = lemon.find(itemprop="ratingValue").text.strip()
        except:
            pass
        try:
            row['Again?'] = lemon.find(class_="make-again-percentage").text.strip()
        except:
            pass
        try:
            if lemon.find('a')['href'] == 'https://www.condenast.com/user-agreement/':
                continue
            else:
                row['URL'] = lemon.find('a')['href']
        except:
            pass
        rows.append(row)
    
# Don't create dataframe until end
print("Building Pandas DataFrame")
df = pd.DataFrame(rows)
# Out:
# Making empty list
# Now scraping https://www.epicurious.com/search/lemon?page=1
# Now scraping https://www.epicurious.com/search/lemon?page=2
# Now scraping https://www.epicurious.com/search/lemon?page=3
# Now scraping https://www.epicurious.com/search/lemon?page=4
# Now scraping https://www.epicurious.com/search/lemon?page=5
# Now scraping https://www.epicurious.com/search/lemon?page=6
# Now scraping https://www.epicurious.com/search/lemon?page=7
# Now scraping https://www.epicurious.com/search/lemon?page=8
# Now scraping https://www.epicurious.com/search/lemon?page=9
# Now scraping https://www.epicurious.com/search/lemon?page=10
# Building Pandas DataFrame

# %%
df.head()
# Out:
#   Again? Rating                                            Summary     Tag  \
# 0   100%      4  The zest of two whole lemons goes into this ca...  recipe
# 1     0%      0  Bright citrus and fresh-ground pepper put a fe...  recipe
# 2    85%      3  Fresh herbs infuse this buttery lemon cake wit...  recipe
# 3     0%      0  Roasting two chickens on one baking sheet is a...  recipe
# 4     0%      0  Whole wheat phyllo dough makes a crispy crust ...  recipe
#
#                                         Title  \
# 0                 East 62nd Street Lemon Cake
# 1                   Lemon-Pepper Salami Bites
# 2          Herb-Infused Lemon-Strawberry Loaf
# 3  Chicken with Lemon and Spicy Spring Onions
# 4   Potato Tart with Mustard Greens and Thyme
#
#                                                  URL
# 0    /recipes/food/views/east-62nd-street-lemon-cake
# 1      /recipes/food/views/lemon-pepper-salami-bites
# 2  /recipes/food/views/herb-infused-lemon-strawbe...
# 3  /recipes/food/views/chicken-with-lemon-and-spi...
# 4  /recipes/food/views/potato-tart-with-mustard-g...

# %%
df.shape
# Out:
# (180, 6)

# %%
df.to_csv("Epicurious.csv", index=False)

# %% [markdown]
# ## Epicurious, Part 2: Once-per-row scraping
# Then, open your search results csv, filter for ONLY recipes. Merge the following fields with your original recipes and save as a new CSV file:
#
# - Ingredients
# - Directions
# - Tags
#
# Tip: If you use .find for your directions/ingredients, it'll print them all on one line. But if you use .find_all to separate them, it makes your life a lot harder! ...unless you just steal this code:

# %%
df = pd.read_csv("Epicurious.csv")
df.shape
# Out:
# (180, 6)

# %%
dfr = df[df.Tag == "recipe"]
dfr.shape
dfr
# Out:
#     Again?  Rating                                            Summary     Tag  \
# 0     100%     4.0  The zest of two whole lemons goes into this ca...  recipe
# 1       0%     0.0  Bright citrus and fresh-ground pepper put a fe...  recipe
# 2      85%     3.0  Fresh herbs infuse this buttery lemon cake wit...  recipe
# 3       0%     0.0  Roasting two chickens on one baking sheet is a...  recipe
# 4       0%     0.0  Whole wheat phyllo dough makes a crispy crust ...  recipe
# 5     100%     4.0  Whatever fruit you have on hand—pears, berries...  recipe
# 6       0%     0.0  Earthy-sweet figs and bright lemon zest and ju...  recipe
# 7       0%     0.0  Cooking summer squash low and slow yields swee...  recipe
# 8     100%     4.0  How to pull off a weeknight roast chicken: set...  recipe
# 9      67%     2.5  If you want to go with the same flavors and ba...  recipe
# 10    100%     4.0  Use this master formula as your guide—but feel...  recipe
# 11      0%     0.0  This is a unique and slightly peculiar British...  recipe
# 13    100%     4.0  In summer, raw corn kernels add crunch and swe...  recipe
# 14      0%     0.0  Bring all your ingredients out to the grill on...  recipe
# 15     86%     3.5  Humble white vinegar does double duty here, te...  recipe
# 18      0%     0.0  The cheesecake has a little lemon in the filli...  recipe
# 20    100%     3.0  Sea bream, common in the Mediterranean, has le...  recipe
# 22     64%     3.0  There may be more sauce than you need to serve...  recipe
# 23      0%     0.0  If you have ever peeled, seeded, and sliced cu...  recipe
# 24    100%     4.0  Fresh grapefruit, lime, and lemon juices balan...  recipe
# 26    100%     4.0  Here the garlic- and lemon-infused pan drippin...  recipe
# 27     88%     3.5  Butterfly your chicken with confidence—the fla...  recipe
# 30    100%     4.0  Toss asparagus ribbons, sliced sugar snap peas...  recipe
# 31     67%     3.5  By constantly stirring the mixture, you'll end...  recipe
# 32    100%     3.5  Get all the flavors of falafel with crispy roa...  recipe
# 34    100%     3.5  Gingersnaps add a hint of spice to this cream ...  recipe
# 35     86%     4.0  It doesn’t take much to make slender, tender g...  recipe
# 36     91%     4.0  Sweet peas, pea shoots, and a sprinkle of lemo...  recipe
# 37      0%     0.0  Transforming cream into butter is one of the m...  recipe
# 38     75%     3.5  Cooking lemon slices just to this side of burn...  recipe
# ..     ...     ...                                                ...     ...
# 131   100%     4.0  This genius dessert—a simple lemon tart perfum...  recipe
# 133     0%     0.0  The most refreshing treat of summer is just a ...  recipe
# 134    88%     3.5  Toss asparagus and frozen peas into boiling li...  recipe
# 135    91%     3.5  Shaping meatballs into perfect spheres is too ...  recipe
# 136   100%     4.0  The uniform thickness of a butterflied boneles...  recipe
# 138    91%     3.5  A scattering of fresh radishes and scallion gr...  recipe
# 139   100%     4.0  This satisfying seafood dinner comes together ...  recipe
# 140   100%     3.0  Cervo’s restaurant in Manhattan serves a brais...  recipe
# 141   100%     4.0  Make the dressing in a food processor if you l...  recipe
# 142   100%     4.0  You don't need a culinary school degree to coo...  recipe
# 143   100%     4.0  We streamlined this recipe to get excellent re...  recipe
# 144     0%     0.0  This simple dish of fresh smashed avocado, rip...  recipe
# 145   100%     1.0  Be sure to roll the meatballs firmly into the ...  recipe
# 146   100%     4.0  For extra chicken flavor, cook flattened bonel...  recipe
# 147   100%     3.5  The sweet, spicy, and tart flavors in this coc...  recipe
# 148   100%     4.0  Slow-roasting salmon is a sure-fire, never-fai...  recipe
# 149   100%     4.0  Toss this simple dressing through an easy summ...  recipe
# 150    75%     3.0  This fresh, vegetable-packed soup is perfect f...  recipe
# 151    80%     3.5  Turn store-bought rotisserie chicken (or lefto...  recipe
# 152     0%     1.0  While smaller squash, such as acorn, can be ro...  recipe
# 153     0%     0.0  This will last for about 2 days in an airtight...  recipe
# 156   100%     3.0  We call this one a picnic dinner since everyth...  recipe
# 157    97%     4.0  Warm feta, crispy chickpeas, and wilted hearty...  recipe
# 158   100%     4.0  This is an antidote to every side salad that e...  recipe
# 160    60%     2.5  The texture of shrimp cooked in the Instant Po...  recipe
# 162   100%     4.0  Spoon this chunky condiment over baked fish, r...  recipe
# 167   100%     3.5  Every Easter when I was growing up, I would wa...  recipe
# 169   100%     4.0  This simple side dish comes together in just a...  recipe
# 173   100%     3.5  Any tender herb or green can be used in this r...  recipe
# 175    88%     3.5  Jarred marinated artichoke hearts get super-cr...  recipe
#
#                                                  Title  \
# 0                          East 62nd Street Lemon Cake
# 1                            Lemon-Pepper Salami Bites
# 2                   Herb-Infused Lemon-Strawberry Loaf
# 3           Chicken with Lemon and Spicy Spring Onions
# 4            Potato Tart with Mustard Greens and Thyme
# 5                                Lemon Cake with Fruit
# 6                               Lemon and Fig Cupcakes
# 7       Slow-Cooked Summer Squash with Lemon and Thyme
# 8    Roast Chicken with Bell Peppers, Lemon, and Thyme
# 9                         Grilled Lemon-Pepper Chicken
# 10    Slow-Cooked Eggplant with Lemon and Fennel Seeds
# 11                               Lemon-Lime Battenberg
# 13              Summer Salad with Lemon Dijon Dressing
# 14   Grilled Pork Chops with Plums, Halloumi, and L...
# 15                                Lemon Chicken Thighs
# 18                                    Lemon Cheesecake
# 20               Sea Bream Crudo with Lemon and Olives
# 22          Chicken Fricassée with Lemon Mustard Sauce
# 23   Smashed Cucumber Salad with Lemon and Celery Salt
# 24              Champagne Punch with Brandy and Citrus
# 26                Za’atar Chicken with Garlicky Yogurt
# 27                             Chicken Under a Skillet
# 30                Spiced Lamb Burgers with Spring Slaw
# 31                                  Classic Lemon Curd
# 32                         Deconstructed Falafel Salad
# 34                         Raspberry-Lemon Icebox Cake
# 35                              Citrusy Haricots Verts
# 36                             Spring Pea Fish Chowder
# 37                               Food Processor Butter
# 38      Chicken and Tomato Stew with Caramelized Lemon
# ..                                                 ...
# 131                         Lemon and Elderflower Tart
# 133                                          Lemon Ice
# 134                               One-Pot Spring Pasta
# 135                         Freeform Chicken Meatballs
# 136                      Grilled Marinated Leg of Lamb
# 138              Instant Pot Brothy Farro with Sausage
# 139              Swordfish Steaks with Asparagus Salad
# 140            Slow-Cooked Squid with Olives and Herbs
# 141                  Green Goddess Tuna Salad Sandwich
# 142                Crispy-Skinned Fish with Herb Sauce
# 143                          Slow-Roasted Bell Peppers
# 144                                        Avo and Egg
# 145                  Fried Meatballs with Tahini Sauce
# 146        Chicken Paillards with Schmaltz Bread Salad
# 147                            Coconut-Turmeric Relish
# 148                   Slow-Roasted Salmon with Harissa
# 149                               Lemon Dijon Dressing
# 150                                    Three-Bean Soup
# 151        Lentil and Chicken Soup with Sweet Potatoes
# 152  Twice-Roasted Squash with Parmesan Butter and ...
# 153                                          Avo Smash
# 156                     10-Minute Shrimp Picnic Dinner
# 157           Baked Feta and Greens with Lemony Yogurt
# 158                                Shaved Fennel Salad
# 160                          Instant Pot Shrimp Scampi
# 162                        Almond and Raisin Agrodolce
# 167                       Poppy Seed and Pecan Strudel
# 169                                   Lemony Asparagus
# 173                               Spring Lamb in Herbs
# 175                 Roasted Niçoise Salad with Halibut
#
#                                                    URL
# 0      /recipes/food/views/east-62nd-street-lemon-cake
# 1        /recipes/food/views/lemon-pepper-salami-bites
# 2    /recipes/food/views/herb-infused-lemon-strawbe...
# 3    /recipes/food/views/chicken-with-lemon-and-spi...
# 4    /recipes/food/views/potato-tart-with-mustard-g...
# 5            /recipes/food/views/lemon-cake-with-fruit
# 6           /recipes/food/views/lemon-and-fig-cupcakes
# 7    /recipes/food/views/slow-cooked-summer-squash-...
# 8    /recipes/food/views/roast-chicken-with-bell-pe...
# 9     /recipes/food/views/grilled-lemon-pepper-chicken
# 10   /recipes/food/views/slow-cooked-eggplant-with-...
# 11       /recipes/food/views/lemon-and-lime-battenberg
# 13   /recipes/food/views/summer-salad-with-lemon-di...
# 14   /recipes/food/views/grilled-pork-chops-with-pl...
# 15            /recipes/food/views/lemon-chicken-thighs
# 18   /recipes/food/views/lemon-ricotta-cheesecake-d...
# 20   /recipes/food/views/sea-bream-crudo-with-lemon...
# 22   /recipes/food/views/chicken-fricassee-with-lem...
# 23   /recipes/food/views/smashed-cucumber-salad-wit...
# 24          /recipes/food/views/champagne-punch-241174
# 26   /recipes/food/views/za-atar-chicken-with-garli...
# 27   /recipes/food/views/chicken-under-a-skillet-wi...
# 30   /recipes/food/views/spiced-lamb-burgers-with-a...
# 31              /recipes/food/views/classic-lemon-curd
# 32     /recipes/food/views/deconstructed-falafel-salad
# 34     /recipes/food/views/raspberry-lemon-icebox-cake
# 35          /recipes/food/views/citrusy-haricots-verts
# 36         /recipes/food/views/spring-pea-fish-chowder
# 37           /recipes/food/views/food-processor-butter
# 38   /recipes/food/views/chicken-and-tomato-stew-wi...
# ..                                                 ...
# 131     /recipes/food/views/lemon-and-elderflower-tart
# 133                      /recipes/food/views/lemon-ice
# 134  /recipes/food/views/one-pot-spring-pasta-with-...
# 135  /recipes/food/views/freeform-chicken-meatballs...
# 136  /recipes/food/views/grilled-marinated-leg-of-l...
# 138  /recipes/food/views/instant-pot-brothy-farro-w...
# 139  /recipes/food/views/swordfish-steaks-with-aspa...
# 140  /recipes/food/views/slow-cooked-squid-with-oli...
# 141  /recipes/food/views/green-goddess-tuna-salad-s...
# 142  /recipes/food/views/crispy-skinned-fish-with-h...
# 143      /recipes/food/views/slow-roasted-bell-peppers
# 144          /recipes/food/views/avocado-and-egg-toast
# 145  /recipes/food/views/deep-fried-beef-and-millet...
# 146  /recipes/food/views/chicken-paillards-with-sch...
# 147        /recipes/food/views/coconut-turmeric-relish
# 148  /recipes/food/views/slow-roasted-salmon-with-h...
# 149  /recipes/food/views/shallot-lemon-dijon-salad-...
# 150                /recipes/food/views/three-bean-soup
# 151  /recipes/food/views/lentil-and-chicken-soup-wi...
# 152  /recipes/food/views/twice-roasted-squash-with-...
# 153                  /recipes/food/views/avocado-smash
# 156  /recipes/food/views/10-minute-shrimp-with-gree...
# 157  /recipes/food/views/baked-feta-and-greens-with...
# 158            /recipes/food/views/shaved-fennel-salad
# 160      /recipes/food/views/instant-pot-shrimp-scampi
# 162    /recipes/food/views/almond-and-raisin-agrodolce
# 167   /recipes/food/views/poppy-seed-and-pecan-strudel
# 169       /recipes/food/views/lemony-sauteed-asparagus
# 173           /recipes/food/views/spring-lamb-in-herbs
# 175  /recipes/food/views/roasted-nicoise-salad-with...
#
# [141 rows x 6 columns]

# %%
rows = []

url = f"https://www.epicurious.com/recipes/food/views/east-62nd-street-lemon-cake"
print("Now scraping", url)

#Download the appropriate page
response = requests.get(url)
doc = BeautifulSoup(response.text)

row = {}
row['Ingredients'] = doc.find(class_="ingredient-groups").text.strip()
row['Directions'] = doc.find(class_="preparation-groups").text.strip()
row['Tags'] = doc.find(class_="tags").text.strip()
# Out:
# Now scraping https://www.epicurious.com/recipes/food/views/east-62nd-street-lemon-cake

# %%
def scrape_page(row):
    url = f"https://www.epicurious.com{row['URL']}"
    print("Scraping:", url)
    
    response = requests.get(url)
    doc = BeautifulSoup(response.text)

    row = {}
    row['Ingredients'] = doc.find(class_="ingredient-groups").text.strip()
    row['Directions'] = doc.find(class_="preparation-groups").text.strip()
    row['Tags'] = doc.find(class_="tags").text.strip()
    
    return pd.Series(row)

# %%
scraped_df = dfr.apply(scrape_page, axis=1) #take df, go through every row, scrape page
# Out:
# Scraping: https://www.epicurious.com/recipes/food/views/east-62nd-street-lemon-cake
#                                          Ingredients  \
# 0  Cake:3 cups sifted unbleached all-purpose flou...
# 1  2 lb. thinly sliced salamiHandfuls of Marcona ...
# 2  3/4 cup (1 1/2 sticks) unsalted butter, plus m...
# 3  1 lemon2 (3 1/2–4-lb.) chickensKosher salt, fr...
# 4  4 sheets whole wheat phyllo dough1 large Yukon...
#
#                                           Directions  \
# 0  For the cake:                                 ...
# 1  Layer salami with some almonds in a shallow bo...
# 2  Preheat oven to 350°F. Butter an 8 1/2x4 1/2" ...
# 3  Preheat oven to 350°F. Very thinly slice 1 lem...
# 4  Preheat the oven to 375°F. Line a 10-inch tart...
#
#                                                 Tags
# 0  Mother's DaySpringCakeBakeLemonSoy FreePeanut ...
# 1  Bon AppétitAppetizerHors D'OeuvrePorkMeatAlmon...
# 2  Mother's DayBrunchDessertBakeCakeButterThymeRo...
# 3  Bon AppétitDinnerChickenSpringGreen Onion/Scal...
# 4  HarperCollinsTartBreakfastBrunchSpringEasterPo...

# %%
scraped_df.shape
# Out:
# (141, 3)

# %%
recipes = dfr.merge(scraped_df, left_index=True, right_index=True)

# %%
recipes.head()
# Out:
#   Again?  Rating                                            Summary     Tag  \
# 0   100%     4.0  The zest of two whole lemons goes into this ca...  recipe
# 1     0%     0.0  Bright citrus and fresh-ground pepper put a fe...  recipe
# 2    85%     3.0  Fresh herbs infuse this buttery lemon cake wit...  recipe
# 3     0%     0.0  Roasting two chickens on one baking sheet is a...  recipe
# 4     0%     0.0  Whole wheat phyllo dough makes a crispy crust ...  recipe
#
#                                         Title  \
# 0                 East 62nd Street Lemon Cake
# 1                   Lemon-Pepper Salami Bites
# 2          Herb-Infused Lemon-Strawberry Loaf
# 3  Chicken with Lemon and Spicy Spring Onions
# 4   Potato Tart with Mustard Greens and Thyme
#
#                                                  URL  \
# 0    /recipes/food/views/east-62nd-street-lemon-cake
# 1      /recipes/food/views/lemon-pepper-salami-bites
# 2  /recipes/food/views/herb-infused-lemon-strawbe...
# 3  /recipes/food/views/chicken-with-lemon-and-spi...
# 4  /recipes/food/views/potato-tart-with-mustard-g...
#
#                                          Ingredients  \
# 0  Cake:3 cups sifted unbleached all-purpose flou...
# 1  2 lb. thinly sliced salamiHandfuls of Marcona ...
# 2  3/4 cup (1 1/2 sticks) unsalted butter, plus m...
# 3  1 lemon2 (3 1/2–4-lb.) chickensKosher salt, fr...
# 4  4 sheets whole wheat phyllo dough1 large Yukon...
#
#                                           Directions  \
# 0  For the cake:                                 ...
# 1  Layer salami with some almonds in a shallow bo...
# 2  Preheat oven to 350°F. Butter an 8 1/2x4 1/2" ...
# 3  Preheat oven to 350°F. Very thinly slice 1 lem...
# 4  Preheat the oven to 375°F. Line a 10-inch tart...
#
#                                                 Tags
# 0  Mother's DaySpringCakeBakeLemonSoy FreePeanut ...
# 1  Bon AppétitAppetizerHors D'OeuvrePorkMeatAlmon...
# 2  Mother's DayBrunchDessertBakeCakeButterThymeRo...
# 3  Bon AppétitDinnerChickenSpringGreen Onion/Scal...
# 4  HarperCollinsTartBreakfastBrunchSpringEasterPo...

# %%
recipes.to_csv("Epicurious-Recipes.csv", index=False)
